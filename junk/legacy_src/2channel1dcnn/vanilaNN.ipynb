# %%
import pandas as pd
import os

# %%
data_path = "/Users/aakashrajput/MachineLearning/Exoplanets/data/inara_1by3/0473216.csv"
sum_d_p = "/Users/aakashrajput/MachineLearning/Exoplanets/data/inara_1by3/summary.csv"

# %%
df = pd.read_csv(data_path)
sum = pd.read_csv(sum_d_p)

# %%
sum.columns
# Out:
# Index(['planet_index', 'star_class', 'star_temperature', 'star_radius',
#        'distance_parsec', 'semimajor_axis', 'planet_radius', 'planet_density',
#        'surface_pressure', 'kappa', 'gamma1', 'gamma2', 'alpha', 'beta',
#        'surface_temperature', 'H2O', 'CO2', 'O2', 'N2', 'CH4', 'N2O', 'CO',
#        'O3', 'SO2', 'NH3', 'C2H6', 'NO2', 'avg_mol_wgt', 'albedo'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['wavelength_(um)', 'star_planet_signal_(erg/s/cm2)',
#        'noise_(erg/s/cm2)', 'stellar_signal_(erg/s/cm2)',
#        'planet_signal_(erg/s/cm2)'],
#       dtype='str')

# %%
sum.shape
# Out:
# (110340, 29)

# %%
sum.head
# Out:
# <bound method NDFrame.head of         planet_index  star_class  star_temperature  star_radius  \
# 0                 40           4       5422.229931     1.013764
# 1                150           3       6662.179144     1.444604
# 2                216           3       6003.359121     1.588907
# 3                219           5       3999.193758     0.697926
# 4                227           4       5790.893132     1.191301
# ...              ...         ...               ...          ...
# 110335       3112486           5       4598.722961     0.838161
# 110336       3112495           3       6745.851509     1.604195
# 110337       3112498           4       5390.134905     1.050666
# 110338       3112571           4       5549.569479     1.051209
# 110339       3112602           3       6672.514314     1.420939
#
#         distance_parsec  semimajor_axis  planet_radius  planet_density  \
# 0              1.900188        1.218159    5407.402319        5.341281
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of        wavelength_(um)  star_planet_signal_(erg/s/cm2)  noise_(erg/s/cm2)  \
# 0             0.200000                    5.661810e-24       1.235270e-19
# 1             0.200105                    5.324610e-24       1.233380e-19
# 2             0.200211                    9.042900e-24       1.231500e-19
# 3             0.200316                    6.383290e-24       1.229620e-19
# 4             0.200421                    5.605860e-24       1.227740e-19
# ...                ...                             ...                ...
# 15341       638.544799                    6.659552e-19       0.000000e+00
# 15342       638.880875                    6.649052e-19       0.000000e+00
# 15343       639.217128                    6.638571e-19       0.000000e+00
# 15344       639.553558                    6.628111e-19       0.000000e+00
# 15345       639.890165                    6.617661e-19       0.000000e+00
#
# ...
